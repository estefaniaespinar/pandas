# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/andressalomferrer/Desktop/pokemon_data.csv/pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#añadir una nueva columna

df['Total'] = df['HP']+df['Attack']+df['Defense']+df['Sp. Atk']+df['Sp. Def']+df['Speed']

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
#how to drop a specific column

df.drop('Total', axis=1)[0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#otra forma más fácil de añadir una columna # 4 pq empieza en HP pero 10 pq el ultimo
#no está incluido así que para que incluya Speed, hemos de poner 10 en vez de 9
#axis 1 para que sume las rows

df['Total'] = df.iloc[:,4:10].sum(axis=1)

# %%
df.head(3)
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Total  Generation  Legendary
# 0    318           1      False
# 1    405           1      False
# 2    525           1      False

# %%
#Cambiar el orden de las columnas

df = df[['Name', 'Type 1','Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total', 'Generation', 'Legendary']]

# %%
df.head(3)
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Total  Generation  Legendary
# 0    318           1      False
# 1    405           1      False
# 2    525           1      False

# %%
##volvemos a poner el Total a lo ultimo para ver como podemos hacerlo de otra forma

df = df[['Name', 'Type 1','Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']]

# %%
df.head(3)
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
##También puedes cambiar el orden de las columnas de una manera más rapida:

cols = list(df.columns.values)
cols
# Out:
# ['Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
#cols [-1] va entre brackets pq cuando pones un solo número lo reconoce como string
# y lo tenemos que pasar a lista ((-1 es para que nos coja el ultimo valor))

df = df[cols[0:4]+[cols[-1]]+cols[4:11]]

# %%
df[0:3]
# Out:
#         Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  Bulbasaur  Grass  Poison  45    318      49       49       65       65
# 1    Ivysaur  Grass  Poison  60    405      62       63       80       80
# 2   Venusaur  Grass  Poison  80    525      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False

# %%
df = df[['Name', 'Type 1','Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']]

# %%
df[0:3]
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525

# %%
##si el -1 nos lia podemos usar el nombre de la columna

df = df[cols[0:4]+['Total']+cols[4:11]]

# %%
df[0:3]
# Out:
#         Name Type 1  Type 2  HP  Total  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  Bulbasaur  Grass  Poison  45    318      49       49       65       65
# 1    Ivysaur  Grass  Poison  60    405      62       63       80       80
# 2   Venusaur  Grass  Poison  80    525      82       83      100      100
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
