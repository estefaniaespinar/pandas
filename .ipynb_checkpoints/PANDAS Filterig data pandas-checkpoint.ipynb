# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/andressalomferrer/Desktop/pokemon_data.csv/pokemon_data.csv')

# %%
#filtrat por una coldicion de row dentro de una columna especifica
df.loc[df['Type 1'] == 'Grass'][0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#filtrar por mas de una columna con condicion:
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')][0:3]

## and en panda es & 
## or en pandas es |

#df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')][0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#Tb podemos filtrar por tres o más conditions

df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 70)]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary
# 2        100     80           1      False
# 3        120     80           1      False
# 50        90     50           1      False
# 77        70     70           1      False
# 652       80     30           5      False

# %%
## Filtrar por rows que contengan en la row la palaba 'mega' or 'Mega'

df.loc[(df['Name'].str.contains('Mega')) | (df['Name'].str.contains('mega'))] [0:3]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %%
#También podemos usar regex
import re

# %%
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)][0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#para que no nos distinga entre mayusculas y minusculas
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)][0:3]
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
#Todas las rows de una columna que empiecen por 'pi'
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)][0:3]
# Out:
#      #       Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  16     Pidgey  Normal  Flying  40      45       40       35       35
# 21  17  Pidgeotto  Normal  Flying  63      60       55       50       50
# 22  18    Pidgeot  Normal  Flying  83      80       75       70       70
#
#     Speed  Generation  Legendary
# 20     56           1      False
# 21     71           1      False
# 22    101           1      False

# %% [markdown]
# ## Conditional changes

# %%
#Cambiar alguna palabra de una columna
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df[3:6]
# Out:
#    #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3  3  VenusaurMega Venusaur   Grass  Poison  80     100      123      122
# 4  4             Charmander  Flamer     NaN  39      52       43       60
# 5  5             Charmeleon  Flamer     NaN  58      64       58       80
#
#    Sp. Def  Speed  Generation  Legendary
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False

# %%
df.agg({'HP':['min','max'], 'Attack':'mean', 'Sp. Atk':['count','mean']})
# Out:
#           HP    Attack  Sp. Atk
# count    NaN       NaN   800.00
# max    255.0       NaN      NaN
# mean     NaN  79.00125    72.82
# min      1.0       NaN      NaN

# %%
# Out:
#          Sp. Atk
#              sum       mean  max
# Type 1
# Bug         3717  53.869565  135
# Dark        2314  74.645161  140
# Dragon      3099  96.843750  180
# Electric    3961  90.022727  165
# Fairy       1335  78.529412  131
# Fighting    1434  53.111111  140
# Flamer      4627  88.980769  159
# Flying       377  94.250000  125
# Ghost       2539  79.343750  170
# Grass       5425  77.500000  145
# Ground      1807  56.468750  150
# Ice         1861  77.541667  130
# Normal      5470  55.816327  135
# Poison      1692  60.428571  100
# Psychic     5609  98.403509  194
# Rock        2787  63.340909  160
# Steel       1823  67.518519  150
# Water       8379  74.812500  180

# %%
df.groupby('Type 1').agg(['sum','mean','max'])
# Out:
#               #                     HP                 Attack              \
#             sum        mean  max   sum       mean  max    sum        mean
# Type 1
# Bug       23080  334.492754  666  3925  56.884058   86   4897   70.971014
# Dark      14302  461.354839  717  2071  66.806452  126   2740   88.387097
# Dragon    15180  474.375000  718  2666  83.312500  125   3588  112.125000
# Electric  15994  363.500000  702  2631  59.795455   90   3040   69.090909
# Fairy      7642  449.529412  716  1260  74.117647  126   1046   61.529412
# Fighting   9824  363.851852  701  1886  69.851852  144   2613   96.777778
# Flamer    17025  327.403846  721  3635  69.903846  115   4408   84.769231
# Flying     2711  677.750000  715   283  70.750000   85    315   78.750000
# Ghost     15568  486.500000  711  2062  64.437500  150   2361   73.781250
# Grass     24141  344.871429  673  4709  67.271429  123   5125   73.214286
# Ground    11401  356.281250  645  2361  73.781250  115   3064   95.750000
# ...

# %%
df.groupby('Type 1').agg(['sum','mean','max'])[['Sp. Atk']]
# Out:
#          Sp. Atk
#              sum       mean  max
# Type 1
# Bug         3717  53.869565  135
# Dark        2314  74.645161  140
# Dragon      3099  96.843750  180
# Electric    3961  90.022727  165
# Fairy       1335  78.529412  131
# Fighting    1434  53.111111  140
# Flamer      4627  88.980769  159
# Flying       377  94.250000  125
# Ghost       2539  79.343750  170
# Grass       5425  77.500000  145
# Ground      1807  56.468750  150
# Ice         1861  77.541667  130
# Normal      5470  55.816327  135
# Poison      1692  60.428571  100
# Psychic     5609  98.403509  194
# Rock        2787  63.340909  160
# Steel       1823  67.518519  150
# Water       8379  74.812500  180

# %%
hola = df.groupby('Type 1').agg('min')[['Attack', 'Speed']].rename(columns = {'Attack':'Bla', 'Speed':'Blabla'})

# %%
hola.head(3)
# Out:
#         Bla  Blabla
# Type 1
# Bug      10       5
# Dark     50      20
# Dragon   50      40
